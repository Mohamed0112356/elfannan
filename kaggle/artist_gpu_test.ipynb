# %% [markdown]
# # ElFannan / الفنان — Kaggle GPU test
#
# This notebook is a remote GPU worker. The source of truth is the ElFannan GitHub repository.

# %%
# %cd /kaggle/working
# !rm -rf ElFannan
# !git clone --depth 1 YOUR_GITHUB_REPO_URL ElFannan
# %cd /kaggle/working/ElFannan

# %%
# !python --version
# !nvidia-smi --query-gpu=name,memory.total,driver_version --format=csv,noheader

# %%
import sys, subprocess
print(sys.version)
import torch
print('torch:', torch.__version__)
print('cuda:', torch.version.cuda)
print('cuda available:', torch.cuda.is_available())
print('gpu count:', torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    p=torch.cuda.get_device_properties(i)
    print(i, p.name, round(p.total_memory/1024**3,2),'GB')

# %%
# !pip install -q -r kaggle/requirements-kaggle.txt

# %%
from pathlib import Path
print(Path.cwd())
print('Kaggle ElFannan environment is ready.')
print('Next: enable a GPU, then install/run exactly one engine per experiment (ACE-Step or RVC).')
